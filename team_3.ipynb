# %% [markdown]
# # Airplane Crashes Since 1908 Data analysis

# %% [markdown]
# Airplane Crashes and Fatalities Since 1908 (Full history of airplane crashes throughout the world, from 1908-present)</br>
# the competition description and data used are available [here](https://github.com/binatnadata/event1-datascience-CEC_CLUB)

# %% [markdown]
# ### Contributors
#
# Within the competitive framework, our team seamlessly contributed to secure the top two position in the Binatnadata competition — an enhancement from our previous participation in the notebook
#
# [Mouad ennasiry](https://www.linkedin.com/in/mouad-en-nasiry-436576217/)
#
#
# [GHita BEN BIH](https://www.linkedin.com/in/ghita-ben-bih-1ab288222?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app)
#
#
# [Mohammed amine hasni](https://www.linkedin.com/in/mohammed-amine-hasni-618924227)
#
#
# [Mouad Sellak](https://www.linkedin.com/in/mouad-sellak?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=ios_app)
#
#
# [ASMAE SALAH](https://www.linkedin.com/in/asmae-salah-b7458721b)
#
#
# [Fatima Ezzahrae  Boukir](https://www.linkedin.com/in/fatima-ezzahrae-boukir-047723219/)
#
#
# [Manar Bakhat](https://www.linkedin.com/in/manar-bakhat/)

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np 
import pandas as pd 
from datetime import date, datetime
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# ## Uploading data

# %%
df= pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')
df.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %% [markdown]
# ### Date:
# Date of accident, in the format - January 01, 200
#
# ### Time:
# Local time, in 24 hr. format unless otherwise specifie
#
# ###Location:
# Location of the acciden
#
# ### Operator:
# Airline or operator of the aircraf
#
# ### Flight #:
# Flight number assigned by the aircraft operato
#
# ### Route:
# Complete or partial route flown prior to the accidence
#
# ### Type:
# Aircraft typ
#
# ### Registration:
# ICAO registration of the aircraf
#
# ### cn/In:
# Construction or serial number / Line or fuselage numbe
#
# ### Aboard:
# Total aboard (passengers / crew)d1

# %% [markdown]
# ## Identifying the probelm:
#
# #### Temporal Trends:
#
# How has the frequency of airplane crashes changed over timcrashes?

# %% [markdown]
# #### Geospatial Analysis:
# What regions or countries have the highest incidence of airplane crashes?

# %% [markdown]
# ### Causal Factors:
# What are the most frequent causes of airplane crashes?

# %% [markdown]
# ## Data types and missing values

# %%
df.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df.shape
# Out:
# (5268, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3561 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
df.describe()
# Out:
#             Aboard   Fatalities       Ground
# count  5246.000000  5256.000000  5246.000000
# mean     27.554518    20.068303     1.608845
# std      43.076711    33.199952    53.987827
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.000000
# max     644.000000   583.000000  2750.000000

# %% [markdown]
# ### Missing values & duplicated rows

# %%
df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1707
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
#missing value percentage of each column
df.isnull().mean() * 100
# Out:
# Date             0.000000
# Time            42.122248
# Location         0.379651
# Operator         0.341686
# Flight #        79.707669
# Route           32.403189
# Type             0.512528
# Registration     6.359150
# cn/In           23.310554
# Aboard           0.417616
# Fatalities       0.227790
# Ground           0.417616
# Summary          7.403189
# dtype: float64

# %%
unique_rows_df = df.drop_duplicates()
d=len(unique_rows_df)-len(df)
print('number of duplicated rows is: '+ str(d))
# Out:
# number of duplicated rows is: 0

# %% [markdown]
# ## Cleaning

# %%
df.drop(['Flight #', 'Registration', 'cn/In'], inplace=True, axis=1)

# %%
df['Route'] = df['Route'].fillna('Not defined')
df['Summary'] = df['Summary'].fillna('No comments')
df['Operator'] = df['Operator'].fillna('Unknown')
df['Type'] = df['Type'].fillna('No Type')
df['Location'] = df['Location'].fillna('unknown')

# %% [markdown]
# ## Feature engineering

# %%
df["Date"]=pd.to_datetime(df['Date'])
df["Year"]=pd.DatetimeIndex(df["Date"]).year
df["Month"]=pd.DatetimeIndex(df["Date"]).month
df["Day"]=pd.DatetimeIndex(df["Date"]).day
df['DayOfWeek'] = pd.DatetimeIndex(df['Date']).day_name()
df['DateOfYear'] = df['Month'].astype(str) +'/'+ df['Day'].astype(str)

# %%
df['survived'] =  df['Aboard']-df["Fatalities"]
df['surviving_ratio']= df["Fatalities"]/df['Aboard']
df['Decade'] = (df['Year']) // 10 * 10

df["Military"] = (df['Operator'].str.contains("Military",regex=False)).astype(int)

df["hijacked"] = (df['Summary'].str.contains("hijack",regex=False)).astype(int)
df['Country']  = df['Location'].str.split(',').str[-1].str.strip().str.upper()

# %%
def military(x):
    if x: return 'Military'
    return ' Non-Military'

df["Military"]=df["Military"].apply(military)

# %%
#determiner les seasons
def get_season(month):
    if month >= 3 and month <= 5:
        return 'Spring'
    elif month >= 6 and month <= 8:
        return 'Summer'
    elif month >= 9 and month <= 11:
        return 'Autumn'
    else:
        return 'Winter'

df['Season'] = df['Month'].apply(get_season)

# %%
#managing time
df['Time'] = pd.to_datetime(df['Time'], format="%H:%M", errors='coerce')
df['hour'] = df['Time'].dt.hour
df['Time'] = df['Time'].dt.strftime('%H:%M')

df_date_index=df.set_index('Date')

# %%
# Apply the function to create a new 'day_night' column
def categorize_day_night(hour):
    if hour>0:
        if 6 <= hour < 18:
            return 'day'
        else:
            return 'night'
    else:
        return "undetermined"
        

df['day_night'] = df['hour'].apply(categorize_day_night)
df['hour'] = df['hour'].fillna(-1).astype(int)
#we filled missing values with -1 to indecate undetermined hour

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Route', 'Type', 'Aboard',
#        'Fatalities', 'Ground', 'Summary', 'Year', 'Month', 'Day', 'DayOfWeek',
#        'DateOfYear', 'survived', 'surviving_ratio', 'Decade', 'Military',
#        'hijacked', 'Country', 'Season', 'hour', 'day_night'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                  0
# Time               2232
# Location              0
# Operator              0
# Route                 0
# Type                  0
# Aboard               22
# Fatalities           12
# Ground               22
# Summary               0
# Year                  0
# Month                 0
# Day                   0
# DayOfWeek             0
# DateOfYear            0
# survived             22
# surviving_ratio      24
# Decade                0
# Military              0
# hijacked              0
# Country               0
# Season                0
# hour                  0
# day_night             0
# dtype: int64

# %%
#df.to_csv('final_df.csv', index=False)

# %% [markdown]
# ## Visualizing by date

# %% [markdown]
# ### visualizing crashes by date

# %%
crashed_by_hour = df[df['hour'] != -1]

crashes_by_hour_count = crashed_by_hour['hour'].value_counts()

crashes_by_hour_count.sort_index().plot(kind='bar', figsize=[6, 4], title='Crashes by Hour', color='red')
plt.xlabel('Hour')
plt.show()

# %%
df['day_night'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(5, 5))
plt.title('Crashes by Day/Night')
plt.ylabel('')  # Remove the default ylabel which is the column name ('day_night')
plt.show()

# %%
df['DayOfWeek'].value_counts().plot(kind='barh', figsize=[6, 4], title='crashes by Day of Week')
plt.show()

# %%
crashed_by_year=df_date_index.resample('1y').size().rolling(3).mean().fillna(0)
crashed_by_year.plot(figsize=[6, 4], title='crashes by Year', ylabel='Total crashes', marker=".")
plt.show()
#measures for safety

# %%
crashed_by_season = df['Season'].groupby(df['Season']).count()

crashed_by_season.plot(kind='bar', figsize=[6, 4], title='crashes by Season')
plt.show()

# %% [markdown]
# ### Visualizing fatilities

# %%
plt.figure(figsize=(6,4))
plt.bar(df['Year'], df['Fatalities'],color='red')
plt.xlabel('Years')
plt.ylabel('Fatalities')
plt.title('Fatalities Over the Years')
plt.show()

# %%
crashed_by_Decade = df['Decade'].groupby(df['Decade']).count()

crashed_by_Decade.plot(kind='bar', figsize=[6, 4], title='crashes by Decade')
plt.show()

# %%
df['DateOfYear'].value_counts().head(10).plot(
    kind='bar', figsize=[6, 4], title='Top 10 Counts of Crashes by Date of the Year')
plt.show()
#new year

# %%
df_date_index["surviving_ratio"].resample('1y').mean().plot(title="Average Surviving ratio per Year", figsize=[6, 4])

plt.axhline(y=df_date_index["surviving_ratio"].mean(), color='r', linestyle='-')

plt.show()

# %% [markdown]
# #### some info about Ground

# %%
df1=df[df['Ground']>0]
print(df1.shape)
# Out:
# (219, 25)

# %%
top_two_indices = df1['Ground'].nlargest(2).index
top_two_rows = df1.loc[top_two_indices, 'Summary']

print("Second Max Row:")
print(top_two_rows.iloc[1])

print("\nMax Ground Row:")
print(df1.loc[df1['Ground'].idxmax(), 'Summary'])
# Out:
# Second Max Row:
# The aircraft was hijacked shortly after it left Logan International Airport in Boston. The hijackers took control of the aircraft and deliberately crashed it into the south tower of the World Trade Center between the 78th and 84th floors at approximately 550 mph. After 56 minutes, the building collapsed. It was one of four planes that were hijacked the same day.
#
# Max Ground Row:
# The aircraft was hijacked shortly after it left Logan International Airport in Boston. The hijackers took control of the aircraft and deliberately crashed it into the north tower of the World Trade Center between the 94th and 99th floors at approximately 450 mph.  After 102 minutes, the building collapsed. It was one of four planes that were hijacked the same day.

# %%
import matplotlib.pyplot as plt

df[df['Summary'].str.contains('hijack', case=False)]['Year'].value_counts().sort_index().plot(
    kind='bar', figsize=[6, 4], title='Count of Hijacked Planes Crashed by Year')
plt.show()

# %%
# Applying a 3-year rolling average to smoothen the 'Aboard,' 'Fatalities,' and 'Survived' series
aboard_year = df[['Aboard', 'Year']].groupby(['Year']).sum()
aboard_year = aboard_year.rolling(3).mean().fillna(0)

fatalities_year = df[['Fatalities', 'Year']].groupby(['Year']).sum()
fatalities_year = fatalities_year.rolling(3).mean().fillna(0)

survived_year = df[['survived', 'Year']].groupby(['Year']).sum()
survived_year = survived_year.rolling(3).mean().fillna(0)

# Extracting the 'Ground' series without applying the moving average
ground_year = df[['Ground', 'Year']].groupby(['Year']).sum()

# Plotting the data with the respective series
plt.figure(figsize=(6, 4))

plt.plot(aboard_year, label='Aboard')
plt.plot(fatalities_year, label='Fatalities')
plt.plot(ground_year, label='Ground')
plt.plot(survived_year, label='Survived')

# Adding legend and labels
plt.legend(title='Passengers')
plt.ylabel('Count')
plt.xlabel('Years')
plt.title('Aboard vs. Ground vs. Fatalities vs. Survived by Year')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Visualing by Location

# %%
df['Location'][df['Location']!='unknown'].value_counts()[:15].sort_values(ascending=True).plot(kind='barh',  figsize=[6, 4], rot=12, fontsize=8)
plt.title("Top 15 countries by crash locations",fontsize=15)
plt.ylabel('Country',fontsize=18)
plt.show()

# %%
# Extracting country information from the 'Location' column in the DataFrame
location_split = df['Location'].str[0:].str.split(',', expand=True)
df['Country'] = location_split[3].fillna(location_split[2]).fillna(location_split[1]).str.strip()

# Creating a list of U.S. states for country assignment
us_states = ['Alabama', 'Alakska', 'Alaska', 'Arizona', 'Arizona', 'Arkansas', 'California', 'California', 
             'California', 'Colorado', 'Colorado', 'Connecticut', 'D.C.', 'Delaware', 'Delaware', 'Florida',
             'Georgia', 'Georgia', 'Hawaii', 'HI', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
             'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 
             'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 
             'New York', 'New York (Idlewild)', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oklahoma',
             'Oregon', 'Pennsylvania', 'Rhode Island', 'South Dakota', 'Tennessee', 'Tennessee', 'Texas', 'United States',
             'Utah', 'Vermont', 'Virginia', 'Virginia', 'Virginia.', 'Washington', 'Washington', 'Washington DC', 'West Virginia',
             'Wisconsin', 'Wisconsin', 'WY']

russian_countries = ['Russian']  # Russia
soviet_countries = ['USSR']  # Soviet Union

cleaned_countries = []
for country in df['Country'].values:
    if country in russian_countries:
         cleaned_countries.append('Russia')
    elif country in us_states:
        cleaned_countries.append('USA')
    elif country in soviet_countries:
        cleaned_countries.append('Soviet Union')
    else:
        cleaned_countries.append(country)

df['Cleaned Country'] = cleaned_countries

fatal_countries = df[['Fatalities', 'Cleaned Country']].groupby(
    ['Cleaned Country']).sum().sort_values('Fatalities', ascending=False)
fatal_countries.reset_index(inplace=True)
fatal_countries.head(10).plot(
    x='Cleaned Country', y='Fatalities', kind='bar', figsize=[6, 4], title='Top 10 Countries by Fatalities',color="red")
plt.xlabel('Country')
plt.ylabel('Fatilities')
plt.show()

# %%
df.groupby(['Operator'])['Fatalities'].sum().sort_values( ascending=False).head(10).sort_values().plot.barh(color='red', figsize=(6,4))
# Douglas DC-3 one of the most airplace that went tough sevrel craches
# USA Russia Brazil are the moust counties by fatalities
#new year period had quite much crashes
#in 70s  crashes reached in peak in then begane decreasing over time due to improved safety measures and technolog
plt.xlabel('Total Fatalities')
plt.ylabel('Route')
plt.title('Top 10 Routes by Total Fatalities')
plt.show()

# %% [markdown]
# ## Visualising by airplane Type/Operator

# %%
df['Type'].value_counts().head(10).sort_values().plot.barh(title='Top 10 counts of craches by airplane type ')
plt.show()

# %%
labels = ['Military', 'Non-Military']
explode = (0.1, 0)

df['Military'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', labels=None, explode=explode, startangle=90, figsize=(5, 5),
    title='Distribution of Crashes by Military Status')

# Adding legend
plt.legend(labels=labels, loc='upper right')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.violinplot(x='Military', y='Fatalities', data=df, palette='Set2',figsize=[6,4])

plt.title('Distribution of Fatalities per Crash by Military Status')
plt.xlabel('Military Status')
plt.ylabel('Fatalities per Crash')

plt.show()

# %% [markdown]
# ## Taking Advantage of Summary

# %%
L=['crashed','Crashed','crew','aircraft','runway','approach','Plane','plane']
text=' '.join(df['Summary'].astype(str))
for i in L:
    text = text.replace(i,"")

wordcloud = WordCloud(width=800, height=400, random_state=21, max_font_size=110, background_color='white').generate(text)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
pilot_error_list = [
    "pilot error", "communication error", "decision-making", "judgment",
    "fatigue", "inadequate", "miscommunication", "coordination",
    "procedural", "overconfidence", "awareness", "incapacitation"
]



mechanical_failure_list = [
    "failure", "technical","issue", "engine", "structural failure",
    "component failure", "equipment failure", "power loss", "gearbox malfunction", "flap malfunction", "brake failure",
    "fuel system", "malfunction", "malfunction", "fuel system malfunction",
 "power outage", "system issue"
]



weather_conditions_list = [
    "weather", "storm", "thunderstorm", "turbulence", "lightning",
    "hailstorm", "icing", "fog", "wind", "low visibility", "precipitation",
    "snowstorm", "freezing rain", "meteorological conditions",
    "weather-related issues", "stormy conditions", "harsh weather", "challenges", "severe weather", "phenomena"
]


air_traffic_control_list = [
    "ATC", "radar issues", "frequency interference", "miscommunication",
    "instruction misinterpretation", "airspace violation", "loss of separation",
    "runway incursion", "airspace congestion", "ILS ",
    "ground control error", "flight plan deviation", "malfunction",
    "controller miscommunication", "misinterpretation of instructions",
    "airspace violation", "loss of separation", "runway incursion",
    "ATC system failure", "airspace congestion", "ILS error", "transponder failure",
    "ground control error", "flight plan deviation", "communication breakdown",
    "challenges"
]


sabotage_terrorism_list = [
    "sabotage", "terrorism", "malicious", "security",
    "hostile action", "terrorist activity", "explosive incident", "hijack",
    "terrorism", "threat", "criminal activity",
    "damage", "suspicious activity", "bomb threat",
    "subversive activity", "unlawful actions", "security threat",
    "hostile intent", "attack attempt", "suspicious activity",
    "threatening incident", "intentional actions"
]


bird_strikes_list = [
    "avian collision", "hazard", "wildlife strike", "feathered collision",
    "interference", "flock collision", "airborne encounter",
    "bird swarm", "activity", "scatter", "bird migration",
    "strike incident", "impact", "wildlife",
    "avian presence", "feathered hazard", "ingestion",
    "related issue", "interference"
]



# Function to count occurrences of words in a list within the 'Summary' column
def count_occurrences(word_list):
    return df['Summary'].str.lower().apply(lambda x: any(word in x for word in word_list)).sum()

result_list = [
    ('Pilot_Error', count_occurrences(pilot_error_list)),
    ('Mechanical_Failure', count_occurrences(mechanical_failure_list)),
    ('Weather_Conditions', count_occurrences(weather_conditions_list)),
    ('Air_Traffic_Control', count_occurrences(air_traffic_control_list)),
    ('Sabotage_Terrorism', count_occurrences(sabotage_terrorism_list)),
    ('bird_strikes_list',count_occurrences(bird_strikes_list))
]

labels, sizes = zip(*result_list)

sizes+=(len(df)-sum(sizes[:-2]),)
labels+=('Unknown',)

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Incident Types')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Regions or Countries with the Highest Incidence of Airplane Crashes:
# - Historically: Parts of Africa, Asia, and South America had higher incidences, but global safety improvements have mitigated risks.
# -
# Notable Aircraft: The Douglas DC-3, despite being one of the most widely used planes, experienced several craehe
# s..
#
#
# ### Frequency of Airplane Crashes Over Time:
# - Trend: Overall, the frequency of airplane crashes has decreased over time due to improved safety measures and technology.
# -
# Fatalities Focus: USA, Russia, and Brazil have been among the countries with the highest fatalities
#
# ### Most Frequent Causes of Airplane Crahes:
#
#
# - Pilot Error: Commonly due to misjudgments or fatigue.
# - Mechanical Failures: Despite advancements, technical issues can occur.
# - Weather Conditions: Adverse weather contributes to accidents.
# - Air Traffic Control Issues: Miscommunications or errors can lead to accidents.
# - Sabotage/Terrorism: Deliberate acts have caused some cr
#
# ### Additional Insights:
#
# - New Year Period: There has been a notable increase in crashes during the New Year period.
# - Historical Peak in 70s: In the 1970s, crashes peaked but began decreasing over time due to improved safety measures and technology.
# - Military vs. Non-Military Aviation:
#     * Military Statistics: Military aviation tends to have more crashes.
#    *
# Fatalities Focus: Despite fewer crashes, non-military aviation may have a noticeable count of fatalities.lities.gy.ashes.craft safety.
